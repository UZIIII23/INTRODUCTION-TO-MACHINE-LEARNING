# %% [markdown]
# ## AUTHOR     : UZAIR-UR-REHMAN
# ## REG ID	  : 22JZELE0471
# ## DEPARTMENT : ELECTRICAL
# ## EMAIL ID   : uzairkhattakh@gmail.com

# %% [markdown]
# ## Lab 10: Multi-Layer Perceptron (MLP) for Time Series Forecasting

# %% [markdown]
# ### Imports Files

# %%
import os
os.chdir(r'D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score
from timeseires.utils.to_split import to_split
from timeseires.utils.multivariate_multi_step import multivariate_multi_step
from timeseires.utils.multivariate_single_step import multivariate_single_step
from timeseires.utils.univariate_multi_step import univariate_multi_step
from timeseires.utils.univariate_single_step import univariate_single_step
from timeseires.utils.CosineAnnealingLRS import CosineAnnealingLRS
from timeseires.callbacks.EpochCheckpoint import EpochCheckpoint
from tensorflow.keras.callbacks import ModelCheckpoint
from timeseires.callbacks.TrainingMonitor import TrainingMonitor
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import LSTM, Bidirectional, Add
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D,TimeDistributed
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,MaxPooling1D,Concatenate,AveragePooling1D, GlobalMaxPooling1D, Input
from tensorflow.keras.models import Sequential,Model
import pandas as pd
import time, pickle
import numpy as np
import tensorflow.keras.backend as K
import tensorflow
from tensorflow.keras.layers import Input, Reshape, Lambda
from tensorflow.keras.layers import Layer, Flatten, LeakyReLU, concatenate, Dense
from tensorflow.keras.regularizers import l2
import glob
import h5py
import matplotlib.pyplot as plt
from keras.callbacks import Callback

# %% [markdown]
# ### Model Architecture

# %%
#lookback = 24
model = None
start_epoch = 0
time_steps=24
num_features=21

# %%
def MLP():
    model = Sequential()
    model.add(Flatten(input_shape=(time_steps , num_features)))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    return model

# %%
model1 = MLP()
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 504)               0
#
#  dense (Dense)               (None, 32)                16160
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 16,193
# Trainable params: 16,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
tensorflow.keras.utils.plot_model(model1 )
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ### Callbacks & Training Setup

# %%
checkpoints = r'D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10\E1-cp-{epoch:04d}-loss{val_loss:.2f}.h5'
OUTPUT_PATH = r'D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10'
FIG_PATH = os.path.sep.join([OUTPUT_PATH,"\history.png"])
JSON_PATH = os.path.sep.join([OUTPUT_PATH,"\history.json"])

# %%
os.path.exists(JSON_PATH)
# Out:
# True

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
EpochCheckpoint1 = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
TrainingMonitor1=TrainingMonitor(FIG_PATH, jsonPath=JSON_PATH, startAt=start_epoch)

# construct the set of callbacks
callbacks = [EpochCheckpoint1,TrainingMonitor1]

# %%
# if there is no specific model checkpoint supplied, then initialize
# the network and compile the model
if model is None:
    print("[INFO] compiling model...")
    model =MLP()
    opt = Adam(1e-3)
    model.compile(loss= 'mae', optimizer=opt, metrics=["mae", "mape"])
# otherwise, load the checkpoint from disk
else:
    print("[INFO] loading {}...".format(model))
    model = load_model(model)

    # update the learning rate
    print("[INFO] old learning rate: {}".format(K.get_value(model.optimizer.lr)))
    K.set_value(model.optimizer.lr, 1e-4)
    print("[INFO] new learning rate: {}".format(K.get_value(model.optimizer.lr)))
# Out:
# [INFO] compiling model...

# %% [markdown]
# ### Data Loading & Preparation

# %%
import os
path_dataset =r'D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10'
path_tr = os.path.join(path_dataset, 'train.csv')
df_tr = pd.read_csv(path_tr)
train_set = df_tr.iloc[:].values
path_v = os.path.join(path_dataset, 'validation.csv')
df_v = pd.read_csv(path_v)
validation_set = df_v.iloc[:].values 
path_te = os.path.join(path_dataset, 'test.csv')
df_te = pd.read_csv(path_te)
test_set = df_te.iloc[:].values 

path_scaler = os.path.join(path_dataset, 'AEP_scaler.pkl')
scaler         = pickle.load(open(path_scaler, 'rb'))

train_set.shape, validation_set.shape, test_set.shape
# Out:
# c:\Users\PMLS\anaconda3\envs\ML\lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.0.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ((860, 21), (90, 21), (30, 21))

# %%
start = time.time()
train_X , train_y = univariate_multi_step(train_set, time_steps, target_col=0,target_len=1)
validation_X, validation_y = univariate_multi_step(validation_set, time_steps, target_col=0,target_len=1)
test_X, test_y = univariate_multi_step(test_set, time_steps, target_col=0,target_len=1)
print('Time Consumed', time.time()-start, "sec")
# Out:
# Time Consumed 0.002693653106689453 sec

# %%
train_X.shape
# Out:
# (835, 24, 21)

# %% [markdown]
# ### Model Training

# %%
epochs = 60
verbose = 1 #0
batch_size = 32
History = model.fit(train_X,
                        train_y,
                        batch_size=batch_size,   
                        epochs = epochs, 
                        validation_data = (validation_X,validation_y),
                        callbacks=callbacks,
                    verbose = verbose)
# Out:
# Epoch 1/60
#  1/27 [>.............................] - ETA: 6s - loss: 0.3454 - mae: 0.3454 - mape: 168.0231WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0007s). Check your callbacks.
#
# Epoch 1: val_loss improved from inf to 0.09448, saving model to D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10\E1-cp-0001-loss0.09.h5
# 27/27 [==============================] - 1s 15ms/step - loss: 0.1864 - mae: 0.1864 - mape: 112.2779 - val_loss: 0.0945 - val_mae: 0.0945 - val_mape: 35.9101
# Epoch 2/60
#  1/27 [>.............................] - ETA: 0s - loss: 0.0775 - mae: 0.0775 - mape: 32.1436
# Epoch 2: val_loss did not improve from 0.09448
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0698 - mae: 0.0698 - mape: 35.5006 - val_loss: 0.1176 - val_mae: 0.1176 - val_mape: 41.0083
# Epoch 3/60
#  1/27 [>.............................] - ETA: 0s - loss: 0.0647 - mae: 0.0647 - mape: 23.7062
# Epoch 3: val_loss did not improve from 0.09448
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0688 - mae: 0.0688 - mape: 35.0442 - val_loss: 0.1298 - val_mae: 0.1298 - val_mape: 45.4287
# Epoch 4/60
#  1/27 [>.............................] - ETA: 0s - loss: 0.0849 - mae: 0.0849 - mape: 33.9112
# Epoch 4: val_loss improved from 0.09448 to 0.07225, saving model to D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10\E1-cp-0004-loss0.07.h5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0593 - mae: 0.0593 - mape: 34.1714 - val_loss: 0.0722 - val_mae: 0.0722 - val_mape: 24.8832
# Epoch 5/60
#  1/27 [>.............................] - ETA: 0s - loss: 0.0532 - mae: 0.0532 - mape: 19.8368
# Epoch 5: val_loss did not improve from 0.07225
# 27/27 [==============================] - 0s 6ms/step - loss: 0.
val_loss did not improve from 0.02584
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0273 - mae: 0.0273 - mape: 13.1473 - val_loss: 0.0370 - val_mae: 0.0370 - val_mape: 11.2998
# Epoch 59/60
#  1/27 [>.............................] - ETA: 0s - loss: 0.0268 - mae: 0.0268 - mape: 12.1591
# Epoch 59: val_loss did not improve from 0.02584
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0245 - mae: 0.0245 - mape: 12.3961 - val_loss: 0.0407 - val_mae: 0.0407 - val_mape: 12.6038
# Epoch 60/60
#  1/27 [>.............................] - ETA: 0s - loss: 0.0582 - mae: 0.0582 - mape: 43.4474
# Epoch 60: val_loss did not improve from 0.02584
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0305 - mae: 0.0305 - mape: 14.8229 - val_loss: 0.0279 - val_mae: 0.0279 - val_mape: 8.2822

# %% [markdown]
# ### Evaluation

# %%
model = load_model(r'D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10\E1-cp-0038-loss0.03.h5')

y_pred_scaled   = model.predict(test_X)
y_pred          = scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler.inverse_transform(test_y)
# Mean Absolute Error (MAE)
MAE = np.mean(abs(y_pred - y_test_unscaled)) 
print('Mean Absolute Error (MAE): ' + str(np.round(MAE, 2)))

# Median Absolute Error (MedAE)
MEDAE = np.median(abs(y_pred - y_test_unscaled))
print('Median Absolute Error (MedAE): ' + str(np.round(MEDAE, 2)))

# Mean Squared Error (MSE)
MSE = np.square(np.subtract(y_pred, y_test_unscaled)).mean()
print('Mean Squared Error (MSE): ' + str(np.round(MSE, 2)))

# Root Mean Squarred Error (RMSE) 
RMSE = np.sqrt(np.mean(np.square(y_pred - y_test_unscaled)))
print('Root Mean Squared Error (RMSE): ' + str(np.round(RMSE, 2)))

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE, 2)) + ' %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Median Absolute Percentage Error (MDAPE): ' + str(np.round(MDAPE, 2)) + ' %')

print('\n\ny_test_unscaled.shape= ',y_test_unscaled.shape)
print('y_pred.shape= ',y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 83ms/step
# Mean Absolute Error (MAE): 5994.69
# Median Absolute Error (MedAE): 6563.31
# Mean Squared Error (MSE): 37090961.38
# Root Mean Squared Error (RMSE): 6090.23
# Mean Absolute Percentage Error (MAPE): 38.4 %
# Median Absolute Percentage Error (MDAPE): 42.33 %
#
#
# y_test_unscaled.shape=  (5, 1)
# y_pred.shape=  (5, 1)

# %% [markdown]
# # Fine Tuning

# %%
checkpoints = r'D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10'
model=r'D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10\E1-cp-0038-loss0.03.h5'
start_epoch= 56

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
EpochCheckpoint1 = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
TrainingMonitor1=TrainingMonitor(FIG_PATH, jsonPath=JSON_PATH, startAt=start_epoch)

# construct the set of callbacks
callbacks = [EpochCheckpoint1,TrainingMonitor1]
# if there is no specific model checkpoint supplied, then initialize
# the network and compile the model
if model is None:
    print("[INFO] compiling model...")
    model = PC.build(time_steps=24, num_features=21, reg=0.0005)
    opt = Adam(1e-3)
    model.compile(loss= 'mae', optimizer=opt, metrics=["mae", "mape"])
# otherwise, load the checkpoint from disk
else:
    print("[INFO] loading {}...".format(model))
    model = load_model(model)

    # update the learning rate
    print("[INFO] old learning rate: {}".format(K.get_value(model.optimizer.lr)))
    K.set_value(model.optimizer.lr, 1e-4)
    print("[INFO] new learning rate: {}".format(K.get_value(model.optimizer.lr)))
# Out:
# [INFO] loading D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10\E1-cp-0038-loss0.03.h5...
# [INFO] old learning rate: 0.0010000000474974513
# [INFO] new learning rate: 9.999999747378752e-05

# %% [markdown]
# ### Model Tranning

# %%
epochs = 10
verbose = 1 #0
batch_size = 32
History = model.fit(train_X,
                        train_y,
                        batch_size=batch_size,   
                        epochs = epochs, 
                        validation_data = (validation_X,validation_y),
                        callbacks=callbacks,
                        verbose = verbose)
# Out:
# Epoch 1/10
#  1/27 [>.............................] - ETA: 3s - loss: 0.0243 - mae: 0.0243 - mape: 15.5783
# Epoch 1: val_loss improved from inf to 0.02963, saving model to D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10
# INFO:tensorflow:Assets written to: D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10\assets
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0255 - mae: 0.0255 - mape: 11.5689 - val_loss: 0.0296 - val_mae: 0.0296 - val_mape: 9.3127
# Epoch 2/10
# 15/27 [===============>..............] - ETA: 0s - loss: 0.0205 - mae: 0.0205 - mape: 9.7404
# Epoch 2: val_loss did not improve from 0.02963
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0201 - mae: 0.0201 - mape: 8.9683 - val_loss: 0.0339 - val_mae: 0.0339 - val_mape: 10.4829
# Epoch 3/10
# 15/27 [===============>..............] - ETA: 0s - loss: 0.0210 - mae: 0.0210 - mape: 9.4887
# Epoch 3: val_loss did not improve from 0.02963
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0196 - mae: 0.0196 - mape: 8.6962 - val_loss: 0.0303 - val_mae: 0.0303 - val_mape: 9.3573
# Epoch 4/10
# 19/27 [====================>.........] - ETA: 0s - loss: 0.0207 - mae: 0.0207 - mape: 10.2189
# Epoch 4: val_loss did not improve from 0.02963
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0202 - mae: 0.0202 - mape: 9.3265 - val_loss: 0.0311 - val_mae: 0.0311 - val_mape: 9.2513
# Epoch 5/10
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0200 - mae: 0.0200 - mape: 8.6078
# Epoch 5: val_loss did not improve from 0.02963
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0201 - mae: 0.0201 - mape: 8.6177 - val_loss: 0.0320 - val_mae: 0.0320 - val_mape: 9.7261
# Epoch 6/10
#  1/27 [>.............................] - ETA: 0s - loss: 0.0175 - mae: 0.0175 - mape: 7.2621
# Epoch 6: val_loss did not improve from 0.02963
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0185 - mae: 0.0185 - mape: 8.0151 - val_loss: 0.0314 - val_mae: 0.0314 - val_mape: 9.6233
# Epoch 7/10
# 16/27 [================>.............] - ETA: 0s - loss: 0.0188 - mae: 0.0188 - mape: 8.1432
# Epoch 7: val_loss did not improve from 0.02963
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0188 - mae: 0.0188 - mape: 8.4207 - val_loss: 0.0312 - val_mae: 0.0312 - val_mape: 9.3559
# Epoch 8/10
# 27/27 [==============================] - ETA: 0s - loss: 0.0190 - mae: 0.0190 - mape: 8.1448
# Epoch 8: val_loss did not improve from 0.02963
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0190 - mae: 0.0190 - mape: 8.1448 - val_loss: 0.0322 - val_mae: 0.0322 - val_mape: 9.6811
# Epoch 9/10
# 12/27 [============>.................] - ETA: 0s - loss: 0.0191 - mae: 0.0191 - mape: 7.6836
# Epoch 9: val_loss did not improve from 0.02963
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0187 - mae: 0.0187 - mape: 7.8015 - val_loss: 0.0330 - val_mae: 0.0330 - val_mape: 9.6126
# Epoch 10/10
# 14/27 [==============>...............] - ETA: 0s - loss: 0.0185 - mae: 0.0185 - mape: 7.5448
# Epoch 10: val_loss did not improve from 0.02963
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0182 - mae: 0.0182 - mape: 7.4833 - val_loss: 0.0354 - val_mae: 0.0354 - val_mape: 10.8584

# %% [markdown]
# ### Model Evaluation

# %%
model = load_model(r'D:\UNIVERSITY\8 SEMESTER\MACHINE LEARNING LAB\LAB 10\E1-cp-0050-loss0.03.h5')

y_pred_scaled   = model.predict(test_X)
y_pred          = scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler.inverse_transform(test_y)
# Mean Absolute Error (MAE)
MAE = np.mean(abs(y_pred - y_test_unscaled)) 
print('Mean Absolute Error (MAE): ' + str(np.round(MAE, 2)))

# Median Absolute Error (MedAE)
MEDAE = np.median(abs(y_pred - y_test_unscaled))
print('Median Absolute Error (MedAE): ' + str(np.round(MEDAE, 2)))

# Mean Squared Error (MSE)
MSE = np.square(np.subtract(y_pred, y_test_unscaled)).mean()
print('Mean Squared Error (MSE): ' + str(np.round(MSE, 2)))

# Root Mean Squarred Error (RMSE) 
RMSE = np.sqrt(np.mean(np.square(y_pred - y_test_unscaled)))
print('Root Mean Squared Error (RMSE): ' + str(np.round(RMSE, 2)))

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE, 2)) + ' %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Median Absolute Percentage Error (MDAPE): ' + str(np.round(MDAPE, 2)) + ' %')

print('\n\ny_test_unscaled.shape= ',y_test_unscaled.shape)
print('y_pred.shape= ',y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 90ms/step
# Mean Absolute Error (MAE): 6140.71
# Median Absolute Error (MedAE): 6873.24
# Mean Squared Error (MSE): 39002601.86
# Root Mean Squared Error (RMSE): 6245.21
# Mean Absolute Percentage Error (MAPE): 39.34 %
# Median Absolute Percentage Error (MDAPE): 44.33 %
#
#
# y_test_unscaled.shape=  (5, 1)
# y_pred.shape=  (5, 1)
